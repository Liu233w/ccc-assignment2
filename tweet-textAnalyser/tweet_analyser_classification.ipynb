# %%
import tweepy
from nltk.corpus import wordnet
import pandas as pd 
import numpy as np 
import pprint

# %%
# Product Topics -----------------------------------------------------------------
# 1) Sport
# 2) IT
# 3) Cooking and Food
# 4) Education
# 5) Pet
# 6) Cosmetic and Fashion
# 7) Car 
# 8) House
# /Product Topics -----------------------------------------------------------------

# %%
topics_list = ['sports', 'tech', 'food', 'pets', 'fashion', 'car', 'house']

# %%
import csv

google_taxonomy_path = '/Users/vihangajayalath/Desktop/UniMelb/Semester 4/Cluster and Cloud Computing/Assignment2/TestData/taxonomy.en-US.txt'

main_categories = []
product_category_dict = {}
with open(google_taxonomy_path) as taxonomy_file:
    for line in taxonomy_file:
        if len(line.split('>')) > 2 and line.split('>')[0] not in product_category_dict.keys():
            product_category_dict[line.split('>')[0]] = {line.split('>')[1]:line.split('>')[2:]}
        elif len(line.split('>')) > 2 and line.split('>')[0] in product_category_dict.keys():
            if line.split('>')[1] in product_category_dict[line.split('>')[0]].keys():
                product_category_dict[line.split('>')[0]][line.split('>')[1]].extend(line.split('>')[2:])
            else:
                product_category_dict[line.split('>')[0]][line.split('>')[1]] = (line.split('>')[2:])

for k,v in product_category_dict.items():
    for i in v.keys():
        v[i] = (list(set(v[i])))
        v[i] = [j.split('\n')[0] for j in v[i]]

# %%
print('Number of High Level Categories: ',len(product_category_dict.keys()))
# Out:
# Number of High Level Categories:  21

# %%
secondary_categories = [list(product_category_dict[key].keys()) for key in product_category_dict.keys()]

# %%
print('Number of Secondary Level Categories: ',sum([len(ite) for ite in secondary_categories]))
# Out:
# Number of Secondary Level Categories:  140

# %%
secondary_categories
# Out:
# [[' Pet Supplies '],
#  [' Clothing ',
#   ' Clothing Accessories ',
#   ' Costumes & Accessories ',
#   ' Handbag & Wallet Accessories ',
#   ' Handbags, Wallets & Cases ',
#   ' Jewelry ',
#   ' Shoe Accessories '],
#  [' Hobbies & Creative Arts ', ' Party & Celebration '],
#  [' Baby Bathing ',
#   ' Baby Health ',
#   ' Baby Safety ',
#   ' Baby Toys & Activity Equipment ',
#   ' Baby Transport ',
#   ' Baby Transport Accessories ',
#   ' Diapering ',
#   ' Nursing & Feeding ',
#   ' Potty Training ',
#   ' Swaddling & Receiving Blankets '],
#  [' Advertising & Marketing ',
#   ' Agriculture ',
#   ' Automation Control Components ',
#   ' Construction ',
#   ' Dentistry ',
#   ' Finance & Insurance ',
#   ' Food Service ',
#   ' Hairdressing & Cosmetology ',
#   ' Heavy Machinery ',
#   ' Industrial Storage ',
#   ' Law Enforcement ',
#   ' Material Handling ',
#   ' Medical ',
#   ' Piercing & Tattooing ',
#   ' Retail ',
#   ' Science & Laboratory ',
#   ' Signage ',
# ...

# %%
from pprint import pprint

# %%
for i in list(product_category_dict.keys()):
    print(str(list(product_category_dict.keys()).index(i)) + ' - ' + i)
# Out:
# 0 - Animals & Pet Supplies
# 1 - Apparel & Accessories
# 2 - Arts & Entertainment
# 3 - Baby & Toddler
# 4 - Business & Industrial
# 5 - Cameras & Optics
# 6 - Electronics
# 7 - Food, Beverages & Tobacco
# 8 - Furniture
# 9 - Hardware
# 10 - Health & Beauty
# 11 - Home & Garden
# 12 - Luggage & Bags
# 13 - Mature
# 14 - Media
# 15 - Office Supplies
# 16 - Religious & Ceremonial
# 17 - Software
# 18 - Sporting Goods
# 19 - Toys & Games
# 20 - Vehicles & Parts

# %%
pprint(product_category_dict[list(product_category_dict.keys())[0]])
# Out:
# {' Pet Supplies ': [' Pet Training Sprays & Solutions',
#                     ' Fish Food',
#                     ' Pet Fragrances & Deodorizing Sprays',
#                     ' Pet Training Pad Holders',
#                     ' Aquarium Cleaning Supplies',
#                     ' Reptile & Amphibian Supplies',
#                     ' Fish Supplies',
#                     ' Small Animal Food',
#                     ' Pet Bowl Mats',
#                     ' Cat Furniture Accessories',
#                     ' Pet Pedometers',
#                     ' Pet Muzzles',
#                     ' Pet First Aid & Emergency Kits',
#                     ' Cat Apparel',
#                     ' Pet Training Aids',
#                     ' Pet Hair Dryers',
#                     ' Reptile & Amphibian Substrates',
#                     ' Dog Diaper Pads & Liners',
#                     ' Dog Apparel',
#                     ' Reptile & Amphibian Habitat Accessories',
#                     ' Dog Food ',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[1]])
# Out:
# {' Clothing ': [' Football Uniforms',
#                 ' Skorts',
#                 ' Dresses',
#                 " Chef's Hats",
#                 ' Suits',
#                 ' Saris & Lehengas',
#                 ' Japanese Black Formal Wear',
#                 ' Bra Accessories',
#                 ' Socks',
#                 ' Bra Strap Pads',
#                 ' Motorcycle Jackets',
#                 ' Ghillie Suits',
#                 ' Baptism & Communion Dresses',
#                 ' Suits ',
#                 ' School Uniforms',
#                 ' Softball Uniforms',
#                 ' Officiating Uniforms',
#                 ' Motorcycle Suits',
#                 ' Food Service Uniforms ',
#                 ' Shapewear',
#                 ' Soccer Uniforms',
#                 ' Uniforms',
#                 ' Hunting Clothing ',
#                 ' Overalls',
#                 ' Pants',
#                 ' Bicycle Shorts & Briefs',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[2]])
# Out:
#       ' Bassoon Bocals',
#                                ' Goblet Drums',
#                                ' Needles & Hooks ',
#                                ' Craft Machine Cases & Covers',
#                                ' Trumpets & Cornets',
#                                ' Musical Cowbells',
#                                ' Clarinet Straps & Supports',
#                                ' Saxophone Pad Savers',
#                                ' Blocking Wires',
#                                ' Harmonica Holders',
#                                ' Guitar Picks',
#                                ' Raw Candle Wax',
#                                ' Clarinet Pad Savers',
#                                ' Woodwind Polishing Cloths',
#                                ' Orchestral String Instrument Accessories ',
#                                ' Orchestral String Instrument Cases',
#                                ' Art & Craft Paint',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[3]])
# Out:
# {' Baby Bathing ': [' Baby Bathtubs & Bath Seats', ' Shower Visors'],
#  ' Baby Health ': [' Pacifiers & Teethers',
#                    ' Nasal Aspirators',
#                    ' Baby Health & Grooming Kits',
#                    ' Pacifier Wipes',
#                    ' Pacifier Clips & Holders'],
#  ' Baby Safety ': [' Baby & Pet Gate Accessories',
#                    ' Baby & Pet Gates',
#                    ' Baby Safety Rails',
#                    ' Baby Monitors',
#                    ' Baby Safety Harnesses & Leashes',
#                    ' Baby Safety Locks & Guards'],
#  ' Baby Toys & Activity Equipment ': [' Alphabet Toys',
#                                       ' Rattles',
#                                       ' Play Mats & Gyms',
#                                       ' Baby Jumpers & Swings',
#                                       ' Sorting & Stacking Toys',
#                                       ' Baby Mobile Accessories',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[4]])
# Out:
# {' Advertising & Marketing ': [' Trade Show Counters',
#                                ' Brochures',
#                                ' Trade Show Displays'],
#  ' Agriculture ': [' Cattle Feed',
#                    ' Pig Feed',
#                    ' Egg Incubators',
#                    ' Livestock Feeders & Waterers',
#                    ' Livestock Feed',
#                    ' Mixed Herd Feed',
#                    ' Chicken Feed',
#                    ' Goat & Sheep Feed',
#                    ' Livestock Halters',
#                    ' Animal Husbandry',
#                    ' Animal Husbandry ',
#                    ' Livestock Feed '],
#  ' Automation Control Components ': [' Variable Frequency & Adjustable Speed '
#                                      'Drives',
#                                      ' Programmable Logic Controllers'],
#  ' Construction ': [' Traffic Cones & Barrels', ' Surveying'],
#  ' Dentistry ': [' Dental Mirrors',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[5]])
# Out:
# {' Camera & Optic Accessories ': [' Camera Silencers & Sound Blimps',
#                                   ' Camera Lens Accessories',
#                                   ' Camera Straps',
#                                   ' Camera Bags & Cases',
#                                   ' Lens & Filter Adapter Rings',
#                                   ' Camera Parts & Accessories',
#                                   ' Thermal Optic Accessories',
#                                   ' Lens Bags',
#                                   ' Underwater Camera Housing Accessories',
#                                   ' Camera Digital Backs',
#                                   ' Rangefinder Accessories',
#                                   ' Video Camera Lights',
#                                   ' Camera Lens Accessories ',
#                                   ' Camera Accessory Sets',
#                                   ' Camera & Optic Replacement Cables',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[6]])
# Out:
# o ',
#              ' Karaoke Systems',
#              ' Signal Processors',
#              ' DJ & Specialty Audio',
#              ' Headsets',
#              ' Speaker Components & Kits',
#              ' Audio Transmitters',
#              ' DJ Systems',
#              ' CD Players & Recorders',
#              ' Reel-to-Reel Tape Players & Recorders',
#              ' Bluetooth Transmitters',
#              ' Headphone & Headset Accessories '],
#  ' Circuit Boards & Components ': [' Circuit Prototyping',
#                                    ' Development Boards',
#                                    ' Television Circuit Boards',
#                                    ' Circuit Prototyping ',
#                                    ' Inductors',
#                                    ' Exercise Machine Circuit Boards',
#                                    ' Microcontrollers',
#                                    ' Electronic Filters',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[7]])
# Out:
# {' Beverages ': [' Tea & Infusions',
#                  ' Milk',
#                  ' Flat Mineral Water',
#                  ' Rum',
#                  ' Juice',
#                  ' Bitters',
#                  ' Hot Chocolate',
#                  ' Vinegar Drinks',
#                  ' Coffee',
#                  ' Fruit Flavored Drinks',
#                  ' Water',
#                  ' Liquor & Spirits ',
#                  ' Cocktail Mixes ',
#                  ' Liqueurs',
#                  ' Powdered Beverage Mixes',
#                  ' Shelf-stable Cocktail Mixes',
#                  ' Flavored Alcoholic Beverages',
#                  ' Spring Water',
#                  ' Carbonated Water',
#                  ' Unflavored Carbonated Water',
#                  ' Beer',
#                  ' Liquor & Spirits',
#                  ' Non-Dairy Milk',
#                  ' Frozen Cocktail Mixes',
#                  ' Alcoholic Beverages',
#                  ' Carbonated Water ',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[8]])
# Out:
# {' Baby & Toddler Furniture ': [' High Chair & Booster Seat Accessories',
#                                 ' Crib & Toddler Bed Accessories',
#                                 ' Crib & Toddler Bed Accessories ',
#                                 ' Crib Conversion Kits',
#                                 ' High Chairs & Booster Seats',
#                                 ' Bassinets & Cradles',
#                                 ' Changing Tables',
#                                 ' Baby & Toddler Furniture Sets',
#                                 ' Bassinet & Cradle Accessories',
#                                 ' Crib Bumpers & Liners',
#                                 ' Cribs & Toddler Beds'],
#  ' Beds & Accessories ': [' Headboards & Footboards',
#                           ' Bed & Bed Frame Accessories',
#                           ' Mattresses',
#                           ' Mattress Foundations',
#                           ' Beds & Bed Frames'],
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[9]])
# Out:
#              ' Lattice',
#                           ' Fence Pickets',
#                           ' Garden Borders & Edging',
#                           ' Fence Panels',
#                           ' Safety & Crowd Control Barriers',
#                           ' Fence Posts & Rails'],
#  ' Fuel ': [' Clear Kerosene',
#             ' Kerosene',
#             ' Home Heating Oil',
#             ' Kerosene ',
#             ' Propane',
#             ' Dyed Kerosene'],
#  ' Hardware Accessories ': [' Twine',
#                             ' Hardware Fasteners ',
#                             ' Cabinet & Furniture Keyhole Escutcheons',
#                             ' Washers',
#                             ' Hinges',
#                             ' Coils',
#                             ' Flagging & Caution Tape',
#                             ' Hooks, Buckles & Fasteners ',
#                             ' Metal Casting Molds',
#                             ' Chain, Wire & Rope ',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[10]])
# Out:
# {' Health Care ': [' Fitness & Nutrition',
#                    ' Biometric Monitors',
#                    ' Blood Pressure Monitor Accessories',
#                    ' Accessibility Equipment',
#                    ' Supports & Braces',
#                    ' Accessibility Furniture & Fixtures ',
#                    ' First Aid Kits',
#                    ' Walkers',
#                    ' Blood Pressure Monitor Cuffs',
#                    ' Activity Monitors',
#                    ' Acupuncture Needles',
#                    ' Contraceptive Cases',
#                    ' Vitamins & Supplements',
#                    ' Bed Pans',
#                    ' Body Weight Scales',
#                    ' Blood Pressure Monitor Accessories ',
#                    ' Walking Aids ',
#                    ' Acupuncture ',
#                    ' Pulse Oximeters',
#                    ' Blood Glucose Meters',
#                    ' Drug Tests',
#                    ' Medical Alarm Systems',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[11]])
# Out:
#                      ' Food Mixer & Blender Accessories',
#                         ' Electric Kettles',
#                         ' Pasta Molds & Stamps',
#                         ' Double Boilers',
#                         ' Vacuum Coffee Makers',
#                         ' Cocktail Shakers & Tools',
#                         ' Food Storage Accessories ',
#                         ' Outdoor Grill Spits & Baskets',
#                         ' Drinkware',
#                         ' Channel Knives',
#                         ' Cookware & Bakeware Combo Sets',
#                         ' Juicers',
#                         ' Beverage Tubs & Chillers',
#                         ' Food Dehydrator Trays',
#                         ' Nutcrackers ',
#                         ' Drink Sleeves ',
#                         ' Jerky Guns',
#                         ' Popcorn & French Fry Scoops',
#                         ' Drinkware ',
#                         ' Baking Weights',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[12]])
# Out:
# {' Luggage Accessories ': [' Travel Bottles & Containers',
#                            ' Dry Box Liners & Inserts',
#                            ' Luggage Racks & Stands',
#                            ' Travel Pouches',
#                            ' Luggage Straps',
#                            ' Luggage Covers',
#                            ' Luggage Tags',
#                            ' Packing Organizers']}

# %%
pprint(product_category_dict[list(product_category_dict.keys())[13]])
# Out:
# {' Erotic ': [' Sex Toys',
#               ' Erotic Games',
#               ' Erotic Clothing',
#               ' Erotic Food & Edibles',
#               ' Pole Dancing Kits',
#               ' Erotic DVDs & Videos',
#               ' Erotic Books',
#               ' Erotic Magazines'],
#  ' Weapons ': [' Gun Holsters',
#                ' Gun Grips',
#                ' Gun Care & Accessories',
#                ' Staff & Stick Weapons',
#                ' Combat Knives',
#                ' Gun Care & Accessories ',
#                ' Brass Knuckles',
#                ' Gun Slings',
#                ' Reloading Supplies & Equipment',
#                ' Gun Cleaning Patches',
#                ' Throwing Stars',
#                ' Stun Guns & Tasers',
#                ' Spears',
#                ' Mace & Pepper Spray',
#                ' Gun Lights',
#                ' Whips',
#                ' Gun Cases & Range Bags',
#                ' Clubs & Batons',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[14]])
# Out:
# {' Books ': [' Audiobooks', ' E-books', ' Print Books'],
#  ' DVDs & Videos ': [' Film & Television DVDs',
#                      ' Film & Television VHS Tapes',
#                      ' Film & Television Digital Downloads'],
#  ' Magazines & Newspapers ': [' Magazines', ' Newspapers'],
#  ' Music & Sound Recordings ': [' Digital Music Downloads',
#                                 ' Music CDs',
#                                 ' Records & LPs',
#                                 ' Spoken Word & Field Recordings',
#                                 ' Music Cassette Tapes'],
#  ' Product Manuals ': [' Office Supply Manuals',
#                        ' Exercise & Fitness Equipment Manuals',
#                        ' Kitchen Appliance Manuals',
#                        ' Household Appliance Manuals',
#                        ' Camera & Optics Manuals',
#                        ' Electronics Manuals',
#                        ' Power Tool & Equipment Manuals',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[15]])
# Out:
# {' Book Accessories ': [' Book Covers',
#                         ' Book Lights',
#                         ' Book Stands & Rests',
#                         ' Bookmarks'],
#  ' Filing & Organization ': [' Binding Supplies ',
#                              ' Recipe Card Boxes',
#                              ' Index Dividers',
#                              ' CD/DVD Cases & Organizers',
#                              ' Business Card Stands',
#                              ' Greeting Card Organizers',
#                              ' Binder Accessories',
#                              ' Folders & Report Covers ',
#                              ' Address Books',
#                              ' Portfolios',
#                              ' Card Files',
#                              ' Mail Sorters',
#                              ' Padfolios',
#                              ' File Boxes',
#                              ' Cash Boxes',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[16]])
# Out:
# {' Memorial Ceremony Supplies ': [' Memorial Urns'],
#  ' Religious Items ': [' Religious Altars',
#                        ' Religious Veils',
#                        ' Tarot Cards',
#                        ' Prayer Cards',
#                        ' Prayer Beads'],
#  ' Wedding Ceremony Supplies ': [' Ring Pillows & Holders',
#                                  ' Aisle Runners',
#                                  ' Flower Girl Baskets']}

# %%
pprint(product_category_dict[list(product_category_dict.keys())[17]])
# Out:
# {' Computer Software ': [' Computer Utilities & Maintenance Software',
#                          ' Operating Systems',
#                          ' Home & Interior Design Software',
#                          ' Multimedia & Design Software',
#                          ' Music Composition Software',
#                          ' Web Design Software',
#                          ' Sound Editing Software',
#                          ' Dictionary & Translation Software',
#                          ' 3D Modeling Software',
#                          ' Financial, Tax & Accounting Software',
#                          ' Restore Disks',
#                          ' Antivirus & Security Software',
#                          ' Multimedia & Design Software ',
#                          ' Graphic Design & Illustration Software',
#                          ' Business & Productivity Software',
#                          ' Video Editing Software',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[18]])
# Out:
#  Locks',
#                           ' Horse Boots & Leg Wraps',
#                           ' Inline & Roller Skating',
#                           ' Hang Gliding & Skydiving',
#                           ' Archery ',
#                           ' Hunting & Wildlife Decoys',
#                           ' Wakeboarding ',
#                           ' Skate Rails',
#                           ' Deck Shuffleboard Pucks',
#                           ' Bicycle Chains',
#                           ' Winter Sports & Activities ',
#                           ' Surf Leashes',
#                           ' Fishing Tackle',
#                           ' Hydration System Accessories',
#                           ' Bows & Crossbows ',
#                           ' Wetsuits',
#                           ' Platform & Paddle Tennis Paddles',
#                           ' Climbing Crash Pads',
#                           ' Tent Vestibules',
#                           ' Bicycle Child Seats',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[19]])
# Out:
# {' Games ': [' Roulette Wheels & Sets',
#              ' Slot Machines',
#              ' Board Games',
#              ' Dice Sets & Games',
#              ' Poker Chips & Sets',
#              ' Poker Chip Carriers & Trays',
#              ' Card Games',
#              ' Blackjack & Craps Sets',
#              ' Battle Top Accessories',
#              ' Battle Tops',
#              ' Card Game Accessories',
#              ' Poker Chip Accessories ',
#              ' Bingo Sets',
#              ' Dexterity Games',
#              ' Poker Chip Accessories',
#              ' Portable Electronic Games',
#              ' Tile Games'],
#  ' Outdoor Play Equipment ': [' Water Play Equipment',
#                               ' Swing Sets & Playsets',
#                               ' Play Swings',
#                               ' Inflatable Bouncers',
#                               ' Stilts',
#                               ' Trampolines',
#                               ' Playhouses',
# ...

# %%
pprint(product_category_dict[list(product_category_dict.keys())[20]])
# Out:
# {' Vehicle Parts & Accessories ': [' Vehicle License Plate Mounts & Holders',
#                                    ' Watercraft Parts & Accessories ',
#                                    ' Motor Vehicle Engine Oil Circulation',
#                                    ' Watercraft Motor Mounts',
#                                    ' Vehicle Shift Knobs',
#                                    ' Vehicle Dashboard Accessories',
#                                    ' Truck Bed Storage Boxes & Organizers',
#                                    ' Watercraft Care ',
#                                    ' Vehicle Bicycle Rack Accessories',
#                                    ' Bumper Stickers',
#                                    ' Motor Vehicle Parts ',
#                                    ' Motor Vehicle Mirrors',
#                                    ' Watercraft Carburetors & Parts',
#                                    ' Motor Vehicle Speakers',
# ...

# %%
def Get_Category_Dict(file_):
    product_categories_df = pd.read_csv(file_, header=None)
    keys_ = list(product_categories_df[3].value_counts().index)
    len_lists = list(product_categories_df[3].value_counts())
    print(sum((len_lists)))
    category_dict = {}

    for k,v in list(zip(keys_, len_lists)):
        category_dict[k] = v

    return category_dict

# %%
shopmania_category_dict_df = pd.DataFrame.from_dict(Get_Category_Dict('shopmania.csv'), orient='index')
filtered_category_df = shopmania_category_dict_df[shopmania_category_dict_df[0] > 1000]

# %%
Get_Category_Dict('shopmania.csv')

# %%
product_categories_df[product_categories_df[3] == 'Football']

# %%
filtered_categories = [i for i in filtered_category_df.index]

# %%
product_categories_df[product_categories_df[3] == 'Calculators']

# %%
product_categories_df[2].value_counts()
